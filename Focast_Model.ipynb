# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings('ignore')

# %%
df.shape
# Out:
# (24084, 9)

# %%
df = pd.read_csv("AzureUsageData.csv")
df.head()
# Out:
#                           SubscriptionName  \
# 0  Microsoft Workxflow Azure Sponsorship 1
# 1  Microsoft Workxflow Azure Sponsorship 1
# 2  Microsoft Workxflow Azure Sponsorship 1
# 3  Microsoft Workxflow Azure Sponsorship 1
# 4  Microsoft Workxflow Azure Sponsorship 1
#
#                        SubscriptionGuid       Date  \
# 0  ce833ac4-dac3-4815-99ef-35765a56dcc3  1/13/2024
# 1  ce833ac4-dac3-4815-99ef-35765a56dcc3   2/5/2024
# 2  ce833ac4-dac3-4815-99ef-35765a56dcc3  1/10/2024
# 3  ce833ac4-dac3-4815-99ef-35765a56dcc3  1/11/2024
# 4  ce833ac4-dac3-4815-99ef-35765a56dcc3  1/12/2024
#
#                            ResourceGuid        ServiceName        ServiceType  \
# 0  c0f5cb45-6fb1-41c9-8545-72ad400d9da4  Azure App Service          Free Plan
# 1  c0f5cb45-6fb1-41c9-8545-72ad400d9da4  Azure App Service          Free Plan
# 2  a90aec9f-eecb-42c7-8421-9b96716996dc  Azure App Service  Free Plan - Linux
# ...

# %%
date = pd.date_range (start = '1/13/2024',end='3/12/2024', freq='M')
date
# Out:
# DatetimeIndex(['2024-01-31', '2024-02-29'], dtype='datetime64[ns]', freq='M')

# %%
df = pd.read_csv('AzureUsageData.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.plot(figsize=(20,8))
plt.title("Cost Vs Quantity")
plt.xlabel("Date")
plt.ylabel("quantity")
plt.grid()

# %%
df = pd.read_csv('AzureUsageData.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6))
plt.plot(df['Cost'].resample('W').sum())
plt.title('Month vs Cost')
plt.xlabel('Date')
plt.ylabel('Cost')
plt.grid(True)
plt.show()

# %%
numberofmonths = 20 
forecast = sarima_result.forecast(steps=numberofmonths)
plt.figure(figsize=(20, 8))
plt.plot(monthly_data, label='Real Values')
plt.plot(forecast, label='Forecast Values')
plt.title('Cost Usage Forecast')
plt.xlabel('Date')
plt.ylabel('Cost')
plt.legend()
plt.grid(True)
plt.show()
